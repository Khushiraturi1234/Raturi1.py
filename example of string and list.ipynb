# %%
#list example

# %%
#10
#list to string 
words = ["join","these","words"]
sentence = " ".join(words)
print(sentence)
# Out:
# join these words

# %%
#9
#Nestd list access
matrix = [[1,2],[3,4]]
print(matrix[1][0])
# Out:
# 3

# %%
#8
#Check Membership
names = ["Alice", "Bob", "Charlie"]
if "Bob" in names:
 print("Found")
# Out:
# Found

# %%
#7 
#list comperission
squares = [x**2 for x in range (6)]
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25]

# %%
#6
#sort and reverse
numbers = [6,3,2,8]
numbers.sort()
numbers.reverse()
print(numbers)
# Out:
# [8, 6, 3, 2]

# %%
#5 
#Remove elemnts
colors = ['red','green','blue']
colors.remove('green')
del colors[0]
print(colors)
# Out:
# ['blue']

# %%
#4 
#add elemnts
l = [1,2,3,4]
l.append(5)
l.insert(1,9)
print(l)
# Out:
# [1, 9, 2, 3, 4, 5]

# %%
#3
#list slicing 
data = [5,6,8,3,9,4]
print(data[2:5])
# Out:
# [8, 3, 9]

# %%
#2
#aCESS ELEMNTS 
num = [10,20,40]
print (num[1])
# Out:
# 20

# %%
#1
#List Creation
fruits = ["apple","banana","cherry"]
print (fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
#string example

# %%
#1
#String concatenation
s1 ="hello"
s2="world"
result = s1 + " " + s2 
print (result)
# Out:
# hello world

# %%
#2 
#string Slicing 
text = "python Programming"
print(text[0:6])
print(text[-6:])
# Out:
# python
# amming

# %%
#3
#string lenght 
s = "learning python"
print(len(s))
# Out:
# 15

# %%
#4 
#Change cases 

s = "artificial Inteligence"
print(s.upper())
print(s.lower())
print(s.title())
# Out:
# ARTIFICIAL INTELIGENCE
# artificial inteligence
# Artificial Inteligence

# %%
#5
#Check palindrom
s = "madam"
if s == s[::-1]:
    print("palindrom")
else:
    print("not a palindrom")
# Out:
# palindrom

# %%
#6 
#Count Charector Frequemcy 
s = "banana"
char_count = s.count('a')
print("Count of 'a':",char_count)
# Out:
# Count of 'a': 3

# %%
#7
#String formating 
name ="Khushi"
age = 19 
print(f"My name is {name} and I am {age} years old ")
# Out:
# My name is Khushi and I am 19 years old

# %%
#8
# Repalce substring 
s = "I love Java"
s = s.replace("Java","Python")
print(s)
# Out:
# I love Python

# %%
#9
#check substring 
s = "data science" 
if "data" in s :
    print("Found")
else:
    print("Not Found")
# Out:
# Found

# %%
#10
#Remove whitespace 
s = " AI and ML"
print(s.strip())
# Out:
# AI and ML
