# %%
s= 'python'
print(sorted(s))
# Out:
# ['h', 'n', 'o', 'p', 't', 'y']

# %%
s='python is a programming language.python is fast. python is my favrouite language.'
c=s.split('.')
print(len(c)-1)
# Out:
# 3

# %%
s1 = 'python'
print(s1[::-2])
# Out:
# nhy

# %%
s = str({1,2,3})
print(s[0])
# Out:
# {

# %%
s= str([1,2,3])
print(s[0])
# Out:
# [

# %%
s= str((1,2,3))
print(s[0])
# Out:
# (

# %%
s= str({1:'c',2:'python',3:'c++'})
print(s[4])
# Out:
# '

# %%
print(s.lower())
# Out:
# {1: 'c', 2: 'python', 3: 'c++'}

# %%
s= 'python'
print(s.capitalize())
# Out:
# Python

# %%
print(s.startswith('v'))
print(s.endswith('n'))
# Out:
# False
# True

# %%
s= 'python python'
print(s.count('python python'))
# Out:
# 1

# %%
print(s.find('z'))
# Out:
# -1

# %%
s='python'
print(s.isalpha())
print(s.isalnum())
print(s.isdigit())
print(s.isupper())
print(s.islower())
# Out:
# True
# True
# False
# False
# True

# %%
if 'py' not in 'python':
    print(True)
else:
    print(False)
# Out:
# False

# %%
for i in 'python':
    print(i,end='\t')
# Out:
# p	y	t	h	o	n
