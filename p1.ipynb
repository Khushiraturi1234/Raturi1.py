# %%
a=6 
print(a)
type(a)
# Out:
# 6
# int

# %%
a=5,6
print(a)
type(a)
# Out:
# (5, 6)
# tuple

# %%
a= True
print(a)
type(a)
# Out:
# True
# bool

# %%
a=6j
print(a)
type(a)
# Out:
# 6j
# complex

# %%
a='p'
print(a)
type(a)
# Out:
# p
# str

# %%
a= [1,2,3,4]
print(a)
type(a)
# Out:
# [1, 2, 3, 4]
# list

# %%
a= (1,4,8 )
print(a)
type(a)
# Out:
# (1, 4, 8)
# tuple

# %%
a= {1,4,8}
print(a)
type(a)
# Out:
# {8, 1, 4}
# set

# %%
a = {1:'python',2:'c',3:'c++'}
print(a)
type(a)
# Out:
# {1: 'python', 2: 'c', 3: 'c++'}
# dict

# %%
#camel case - pythonName, myNameIs
#pascal = PythonName
#snake = Python_name 
a,b,c = 5,6,7
a = b = c = 10 
a,b=b,a

# %%
s = 'python'
print(s)
# Out:
# python

# %%
print(f'my string is : {s}')
# Out:
# my string is : python

# %%
a = range(5)
print(a)
# Out:
# range(0, 5)

# %%
#single line comment 
"multi line coment"
# Out:
# 'multi line coment'

# %%
#opreators : arthmetic, comperision, identity, membership,assingnmnet, bitwise
#athmetic : +,-,*,/,
#comparision : >,<,<=,>=,==,|=
#identity : is, not, us
#membership : a=5, a+=5, a-=5, a%=5
