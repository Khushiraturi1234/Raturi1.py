# %%
s = 'python'
s[-5:]
# Out:
# 'ython'

# %%
s[-5:-1:2]
# Out:
# 'yh'

# %%
s[-1::-1]
# Out:
# 'nohtyp'

# %%
#list concatenation
l1 = ['python',3.13,10]
l2 = ['c',23.0,11]
l3 = l1+l2
l3
# Out:
# ['python', 3.13, 10, 'c', 23.0, 11]

# %%
type(l3)
# Out:
# list

# %%
l3 = list((11,5,3))
l3
# Out:
# [11, 5, 3]

# %%
l3.extend([5,6,7])
l3
# Out:
# [11, 5, 3, 5, 6, 7, 5, 6, 7]

# %%
l3.append([567])
l3
# Out:
# [11, 5, 3, 5, 6, 7, 5, 6, 7, [567], [567]]

# %%
l2.insert(2,'c')
l2
# Out:
# ['c', 23.0, 'c', 'c', 11]

# %%
l3 =[4,8,1,14,10]
l3.sort()
l3
# Out:
# [1, 4, 8, 10, 14]

# %%
l3 =[4,8,1,14,10]
sorted(l3)
# Out:
# [1, 4, 8, 10, 14]

# %%
l3.pop(0)
# Out:
# 4

# %%
l3 =[4,8,1,14,10]
l3.remove(1)
l3
# Out:
# [4, 8, 14, 10]

# %%
l3 =[4,8,1,14,10]
l3.index(1)
# Out:
# 2

# %%
#list slicing

# %%
l = [22,44,66,99,100,232,34]
print(l)
# Out:
# [22, 44, 66, 99, 100, 232, 34]

# %%
l = [22,44,66,99,100,232,34]
l[1:4]
# Out:
# [44, 66, 99]

# %%
l[2:]
# Out:
# [66, 99, 100, 232, 34]

# %%
l[-2]
# Out:
# 232

# %%
l[::2]
# Out:
# [22, 66, 100, 34]

# %%
print(l[:])
# Out:
# [22, 44, 66, 99, 100, 232, 34]

# %%
l + [66]
# Out:
# [22, 44, 66, 99, 100, 232, 34, 66]

# %%
len(l*6)
# Out:
# 42

# %%
sum(l)
# Out:
# 597

# %%
sorted(l)
#it sort list into new list not in the orignal list
# Out:
# [22, 34, 44, 66, 99, 100, 232]

# %%
l.append([1 ,2 ,3])
print(l)
# Out:
# [22, 44, 66, 99, 100, 232, 34, [1, 2, 3]]

# %%
l.extend([1,2,3])
print(l)
# Out:
# [22, 44, 66, 99, 100, 232, 34, [1, 2, 3], 1, 2, 3, 1, 2, 3]

# %%
l.pop(6)
print(l)
# Out:
# [22, 44, 66, 100, 232, 34, 3, 1, 2, 3]

# %%
l.remove(232)
print(l)
# Out:
# [22, 44, 66, 100, 34, 3, 1, 2, 3]

# %%
l.count(3)
#count how many times the no come
# Out:
# 2

# %%
boolen_list = [True,False]
boolen_list.sort(reverse= True)
print(boolen_list)
# Out:
# [True, False]

# %%
l.reverse()
print(l)
# Out:
# [3, 2, 1, 3, 34, 100, 66, 44, 22]

# %%
l.sort(reverse=True)
print(l)
#the l.sort(reverse= True ) change the list in assending order
# Out:
# [100, 66, 44, 34, 22, 3, 3, 2, 1]

# %%
l1 = [1,2,34,5]
l2= [4,8,7]
l1 + l2
# Out:
# [1, 2, 34, 5, 4, 8, 7]
