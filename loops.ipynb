# %%
l = [1,4,2,7]
for i in l:
    print(i)
# Out:
# 1
# 4
# 2
# 7

# %%
t = (1,4,2,7)
for i in t:
    print(i)
# Out:
# 1
# 4
# 2
# 7

# %%
s ={1,4,2,7}
for i in s :
    print (i)
# Out:
# 1
# 2
# 4
# 7

# %%
d = {1:'c',2:'python',3:'c++'}
for i, j in d.items():
    print(i,j)
print(d.keys())
print(d.values())
# Out:
# 1 c
# 2 python
# 3 c++
# dict_keys([1, 2, 3])
# dict_values(['c', 'python', 'c++'])

# %%
s = 'python'
for i in s: 
    print(s.index(i))
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
s= 'python'
sl = len(s)
for i in range(1,sl,2):
    print(s[i])
# Out:
# y
# h
# n

# %%
l = [2,17,4,34]
i=0
while i<len(l):
    print(i)
    i+=1
# Out:
# 0
# 1
# 2
# 3
