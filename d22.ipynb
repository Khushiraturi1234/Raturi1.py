# %%
#assingment statement

# %%
x=3
print(1+1)
print(len("hello Team almabetter"))
# Out:
# 2
# 21

# %%
y =3.14
y
# Out:
# 3.14

# %%
a = 'Mighty'
#b=a==True
a == True
# Out:
# False

# %%
#Multiline Comment

# %%
x=1
y=2
+5
z=3
y
# Out:
# 2

# %%
my_list = [1]
my_tuple = (1,)
my_list , my_tuple
# Out:
# ([1], (1,))
