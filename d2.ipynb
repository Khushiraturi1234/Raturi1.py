# %%
#single line comment 
'''multi line comment'''
# Out:
# 'multi line comment'

# %%
#type Casting 
a = 5 
b = float(a)
print (b)
print(type(b))
# Out:
# 5.0
# <class 'float'>

# %%
a=5
b=str(a)
print(b)
print(type(b))
# Out:
# 5
# <class 'str'>

# %%
a = True 
b = float (a)
print(b)
print(type(b))
# Out:
# 1.0
# <class 'float'>

# %%
l = [1,4,2,7]
s = str(1)
print(s)
print(type(s))
# Out:
# 1
# <class 'str'>

# %%
print(s[0])
# Out:
# 1

# %%
l= (1,4,2,7)
s = str(1)
print(s)
print(type(s))
# Out:
# 1
# <class 'str'>

# %%
l = {1:'c',2:'c++', 3:'python'}
s = str(l)
print(s)
print(type(s))
# Out:
# {1: 'c', 2: 'c++', 3: 'python'}
# <class 'str'>

# %%
l = {1:'c',2:'c++', 3:'python'}
s = list(l)
print(s)
print(type(s))
# Out:
# [1, 2, 3]
# <class 'list'>
